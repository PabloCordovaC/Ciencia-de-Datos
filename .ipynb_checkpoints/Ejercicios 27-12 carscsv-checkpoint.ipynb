# %%
import pandas as pd
pd.options.display.max_columns = None
import matplotlib.pyplot as plt
plt.style.use("seaborn-dark")

# %%
df = pd.read_csv("cars.csv")

# %%
df.head()
# Out:
#   manufacturer_name model_name transmission   color  odometer_value  \
# 0            Subaru    Outback    automatic  silver          190000
# 1            Subaru    Outback    automatic    blue          290000
# 2            Subaru   Forester    automatic     red          402000
# 3            Subaru    Impreza   mechanical    blue           10000
# 4            Subaru     Legacy    automatic   black          280000
#
#    year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# 0           2010    gasoline           False    gasoline              2.5
# 1           2002    gasoline           False    gasoline              3.0
# 2           2001    gasoline           False    gasoline              2.5
# 3           1999    gasoline           False    gasoline              3.0
# 4           2001    gasoline           False    gasoline              2.5
#
#    body_type  has_warranty  state drivetrain  price_usd  is_exchangeable  \
# ...

# %%
df.dtypes
# Out:
# manufacturer_name     object
# model_name            object
# transmission          object
# color                 object
# odometer_value         int64
# year_produced          int64
# engine_fuel           object
# engine_has_gas          bool
# engine_type           object
# engine_capacity      float64
# body_type             object
# has_warranty            bool
# state                 object
# drivetrain            object
# price_usd            float64
# is_exchangeable         bool
# location_region       object
# number_of_photos       int64
# up_counter             int64
# feature_0               bool
# feature_1               bool
# feature_2               bool
# feature_3               bool
# feature_4               bool
# feature_5               bool
# feature_6               bool
# feature_7               bool
# feature_8               bool
# feature_9               bool
# duration_listed        int64
# dtype: object

# %%
df.describe()
# Out:
#        odometer_value  year_produced  engine_capacity     price_usd  \
# count    38531.000000   38531.000000     38521.000000  38531.000000
# mean    248864.638447    2002.943734         2.055161   6639.971021
# std     136072.376530       8.065731         0.671178   6428.152018
# min          0.000000    1942.000000         0.200000      1.000000
# 25%     158000.000000    1998.000000         1.600000   2100.000000
# 50%     250000.000000    2003.000000         2.000000   4800.000000
# 75%     325000.000000    2009.000000         2.300000   8990.000000
# max    1000000.000000    2019.000000         8.000000  50000.000000
#
#        number_of_photos    up_counter  duration_listed
# count      38531.000000  38531.000000     38531.000000
# mean           9.649062     16.306091        80.577249
# std            6.093217     43.286933       112.826569
# min            1.000000      1.000000         0.000000
# 25%            5.000000      2.000000        23.000000
# ...

# %% [markdown]
# Medidas de tendencia central ( media(promedio), mediana y moda

# %%
df['price_usd'].mean()
# Out:
# 6639.971021255604

# %%
df['price_usd'].median()
# Out:
# 4800.0

# %%
df['price_usd'].std()
# Out:
# 6428.152018202915

# %%
df['price_usd'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['price_usd'].plot.hist(bins = 20, edgecolor ="red")
plt.show()

# %%
df['year_produced'].plot.hist(bins = 50, edgecolor ="red")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import seaborn as sns

# %%
sns.displot(df,x='price_usd', hue = 'manufacturer_name')
plt.show()

# %%
sns.displot(df,x='price_usd', hue = 'engine_type', multiple = 'stack')
plt.show()

# %%
df.groupby('engine_type').count()
# Out:
#              manufacturer_name  model_name  transmission  color  \
# engine_type
# diesel                   12874       12874         12874  12874
# electric                    10          10            10     10
# gasoline                 25647       25647         25647  25647
#
#              odometer_value  year_produced  engine_fuel  engine_has_gas  \
# engine_type
# diesel                12874          12874        12874           12874
# electric                 10             10           10              10
# gasoline              25647          25647        25647           25647
#
#              engine_capacity  body_type  has_warranty  state  drivetrain  \
# engine_type
# diesel                 12874      12874         12874  12874       12874
# electric                   0         10            10     10          10
# gasoline               25647      25647         25647  25647       25647
#
#              price_usd  is_exchangeable  location_region  number_of_photos  \
# ...

# %%
# buscar un Audi Q7
Q7_df = df[(df['manufacturer_name']=='Audi')& (df['model_name']=='Q7')]
Q7_df.iloc[:]
# Out:
#       manufacturer_name model_name transmission   color  odometer_value  \
# 19515              Audi         Q7    automatic    grey          275000
# 19547              Audi         Q7    automatic   white          105000
# 19559              Audi         Q7    automatic   other          170000
# 19574              Audi         Q7    automatic   black          185000
# 19583              Audi         Q7    automatic   other          210000
# ...                 ...        ...          ...     ...             ...
# 21756              Audi         Q7    automatic  silver          200000
# 21812              Audi         Q7    automatic   black          276000
# 21873              Audi         Q7    automatic   black          273000
# 21900              Audi         Q7    automatic   white          283000
# 21942              Audi         Q7    automatic    grey          262000
#
#        year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# ...

# %%
Q7_df
# Out:
#       manufacturer_name model_name transmission   color  odometer_value  \
# 19515              Audi         Q7    automatic    grey          275000
# 19547              Audi         Q7    automatic   white          105000
# 19559              Audi         Q7    automatic   other          170000
# 19574              Audi         Q7    automatic   black          185000
# 19583              Audi         Q7    automatic   other          210000
# ...                 ...        ...          ...     ...             ...
# 21756              Audi         Q7    automatic  silver          200000
# 21812              Audi         Q7    automatic   black          276000
# 21873              Audi         Q7    automatic   black          273000
# 21900              Audi         Q7    automatic   white          283000
# 21942              Audi         Q7    automatic    grey          262000
#
#        year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# ...

# %%
sns.histplot(Q7_df, x= 'price_usd',  hue ='year_produced')
plt.show()

# %%
sns.histplot(Q7_df, x= 'odometer_value',  hue ='year_produced')
plt.show()

# %%
df[(df['manufacturer_name']=='Subaru')].count()
# Out:
# manufacturer_name    291
# model_name           291
# transmission         291
# color                291
# odometer_value       291
# year_produced        291
# engine_fuel          291
# engine_has_gas       291
# engine_type          291
# engine_capacity      291
# body_type            291
# has_warranty         291
# state                291
# drivetrain           291
# price_usd            291
# is_exchangeable      291
# location_region      291
# number_of_photos     291
# up_counter           291
# feature_0            291
# feature_1            291
# feature_2            291
# feature_3            291
# feature_4            291
# feature_5            291
# feature_6            291
# feature_7            291
# feature_8            291
# feature_9            291
# duration_listed      291
# dtype: int64

# %%
df.groupby(df['manufacturer_name']== 'Subaru').count()
# Out:
#                    manufacturer_name  model_name  transmission  color  \
# manufacturer_name
# False                          38240       38240         38240  38240
# True                             291         291           291    291
#
#                    odometer_value  year_produced  engine_fuel  engine_has_gas  \
# manufacturer_name
# False                       38240          38240        38240           38240
# True                          291            291          291             291
#
#                    engine_type  engine_capacity  body_type  has_warranty  \
# manufacturer_name
# False                    38240            38230      38240         38240
# True                       291              291        291           291
#
#                    state  drivetrain  price_usd  is_exchangeable  \
# manufacturer_name
# False              38240       38240      38240            38240
# True                 291         291        291              291
#
# ...

# %%
df[(df['manufacturer_name']=='Subaru')& (df['model_name'].count())]
# Out:
#     manufacturer_name model_name transmission   color  odometer_value  \
# 0              Subaru    Outback    automatic  silver          190000
# 1              Subaru    Outback    automatic    blue          290000
# 2              Subaru   Forester    automatic     red          402000
# 3              Subaru    Impreza   mechanical    blue           10000
# 4              Subaru     Legacy    automatic   black          280000
# ..                ...        ...          ...     ...             ...
# 286            Subaru   Forester    automatic   other          170000
# 287            Subaru     Legacy   mechanical   black          150000
# 288            Subaru   Forester    automatic  violet          275471
# 289            Subaru     Legacy    automatic   white          225308
# 290            Subaru    Outback    automatic   green          233355
#
#      year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# ...

# %%
SI_df = df[(df['manufacturer_name']=='Subaru')& (df['model_name']=='Impreza')]
SI_df.iloc[:]
# Out:
#     manufacturer_name model_name transmission   color  odometer_value  \
# 3              Subaru    Impreza   mechanical    blue           10000
# 17             Subaru    Impreza   mechanical    blue          191000
# 28             Subaru    Impreza   mechanical   black          300000
# 32             Subaru    Impreza   mechanical  violet          340000
# 34             Subaru    Impreza   mechanical  silver          118000
# 35             Subaru    Impreza    automatic   black          246113
# 51             Subaru    Impreza   mechanical    blue          143000
# 71             Subaru    Impreza   mechanical     red          363500
# 84             Subaru    Impreza   mechanical    blue          130000
# 89             Subaru    Impreza   mechanical   green          329786
# 90             Subaru    Impreza   mechanical     red          230000
# 93             Subaru    Impreza    automatic  silver           80000
# ...

# %%
sns.histplot(SI_df, x= 'price_usd',  hue ='year_produced',multiple = 'stack')
plt.show()

# %%
SI_df.describe()
# Out:
#        odometer_value  year_produced  engine_capacity     price_usd  \
# count       42.000000      42.000000        42.000000     42.000000
# mean    214564.547619    2004.166667         2.016667   6863.427857
# std      96820.562435       5.463478         0.342100   4044.388600
# min      10000.000000    1993.000000         1.500000    948.500000
# 25%     146000.000000    1999.000000         2.000000   3449.750000
# 50%     192000.000000    2005.500000         2.000000   6575.000000
# 75%     285250.000000    2008.000000         2.000000   9794.250000
# max     465000.000000    2016.000000         3.000000  14950.000000
#
#        number_of_photos  up_counter  duration_listed
# count         42.000000   42.000000        42.000000
# mean           9.452381   21.380952       120.404762
# std            6.829643   30.746765       122.234692
# min            1.000000    1.000000         4.000000
# 25%            4.000000    2.000000        48.250000
# ...

# %%
sns.histplot(SI_df, x= 'price_usd',  hue ='model_name')
plt.show()

# %%
SI_df.groupby('year_produced').count()
# Out:
#                manufacturer_name  model_name  transmission  color  \
# year_produced
# 1993                           1           1             1      1
# 1994                           2           2             2      2
# 1997                           2           2             2      2
# 1998                           4           4             4      4
# 1999                           3           3             3      3
# 2001                           1           1             1      1
# 2002                           2           2             2      2
# 2003                           2           2             2      2
# 2005                           4           4             4      4
# 2006                           4           4             4      4
# 2007                           4           4             4      4
# 2008                           5           5             5      5
# 2009                           3           3             3      3
# ...

# %%
si1 =SI_df[SI_df['year_produced'] >=2008]
si1
# Out:
#     manufacturer_name model_name transmission   color  odometer_value  \
# 34             Subaru    Impreza   mechanical  silver          118000
# 35             Subaru    Impreza    automatic   black          246113
# 51             Subaru    Impreza   mechanical    blue          143000
# 84             Subaru    Impreza   mechanical    blue          130000
# 93             Subaru    Impreza    automatic  silver           80000
# 101            Subaru    Impreza    automatic   black          205328
# 114            Subaru    Impreza   mechanical   other          185000
# 116            Subaru    Impreza   mechanical  silver          193000
# 135            Subaru    Impreza    automatic    grey           95000
# 210            Subaru    Impreza   mechanical   white           98000
# 253            Subaru    Impreza   mechanical  silver           58270
# 254            Subaru    Impreza    automatic  silver          222000
# ...

# %%
sns.histplot(si1, x= 'price_usd',  hue ='year_produced', multiple = 'stack')
plt.show()

# %%
sns.histplot(si1, x= 'year_produced',  y='price_usd',edgecolor ="black",multiple = 'stack',bins = 16, hue='price_usd')
plt.show()

# %%
SI_df['year_produced'].plot.hist(bins = 25, edgecolor ="red")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.histplot(SI_df, x= 'year_produced',  y='price_usd',bins = 25,edgecolor ="black")
plt.show()
